# %%
import pandas as pd
import numpy as np
import csv

# %%
ratings_csv = pd.read_csv("dataset/ratings.csv")
book_tags_csv = pd.read_csv("dataset/book_tags.csv")
books_csv = pd.read_csv("dataset/books.csv")
tags_csv = pd.read_csv("dataset/tags.csv")
to_read_csv = pd.read_csv("dataset/to_read.csv")

# %%
ratings_csv.head()
# Out:
#    user_id  book_id  rating
# 0        1      258       5
# 1        2     4081       4
# 2        2      260       5
# 3        2     9296       5
# 4        2     2318       3

# %%
book_tags_csv.head()
# Out:
#    goodreads_book_id  tag_id   count
# 0                  1   30574  167697
# 1                  1   11305   37174
# 2                  1   11557   34173
# 3                  1    8717   12986
# 4                  1   33114   12716

# %%
for i in books_csv.columns:
    print(i)
books_csv.head(500)
# Out:
# book_id
# goodreads_book_id
# best_book_id
# work_id
# books_count
# isbn
# isbn13
# authors
# original_publication_year
# original_title
# title
# language_code
# average_rating
# ratings_count
# work_ratings_count
# work_text_reviews_count
# ratings_1
# ratings_2
# ratings_3
# ratings_4
# ratings_5
# image_url
# small_image_url
#      book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 0          1            2767052       2767052   2792775          272
# 1          2                  3             3   4640799          491
# 2          3              41865         41865   3212258          226
# 3          4               2657          2657   3275794          487
# 4          5               4671          4671    245494         1356
# 5          6           11870085      11870085  16827462          226
# 6          7               5907          5907   1540236          969
# 7          8               5107          5107   3036731          360
# ...

# %%
tags_csv.head()
# Out:
#    tag_id tag_name
# 0       0        -
# 1       1     --1-
# 2       2    --10-
# 3       3    --12-
# 4       4   --122-

# %%
to_read_csv.head()
# Out:
#    user_id  book_id
# 0        9        8
# 1       15      398
# 2       15      275
# 3       37     7173
# 4       34      380

# %%
users = ratings_csv['user_id'].unique()
users.sort()
print(len(users))
books = ratings_csv['book_id'].unique()
books.sort()
print(len(books))
oldi = 0
# Out:
# 53424
# 10000

# %%
'''
fields = ['user_id', 'Name', 'username', 'password']
rows = []
name = 'user'
pwd = 'password'
for i in users:
    l = [i, name+str(i), name+str(i), pwd]
    rows.append(l)
'''
# Out:
# "\nfields = ['user_id', 'Name', 'username', 'password']\nrows = []\nname = 'user'\npwd = 'password'\nfor i in users:\n    l = [i, name+str(i), name+str(i), pwd]\n    rows.append(l)\n"

# %%
'''
with open('users.csv', 'w') as csvfile:  
    csvwriter = csv.writer(csvfile) 
    csvwriter.writerow(fields)
    csvwriter.writerows(rows)
'''

# %%
users_csv = pd.read_csv("dataset/users.csv")
users_csv.head()
# Out:
#    user_id   Name username  password
# 0        1  user1    user1  password
# 1        2  user2    user2  password
# 2        3  user3    user3  password
# 3        4  user4    user4  password
# 4        5  user5    user5  password

# %%
print(books_csv['image_url'][0])
print(books_csv['small_image_url'][0])
# Out:
# https://images.gr-assets.com/books/1447303603m/2767052.jpg
# https://images.gr-assets.com/books/1447303603s/2767052.jpg
